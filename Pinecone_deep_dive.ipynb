# %% [markdown]
# # Pinecone

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
pip install -q pinecone
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade -q pinecone
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show pinecone
# Out:
# Name: pinecone
# Version: 6.0.1
# Summary: Pinecone client and SDK
# Home-page: https://www.pinecone.io
# Author: Pinecone Systems, Inc.
# Author-email: support@pinecone.io
# License: Apache-2.0
# Location: /Users/pandagan/workspace/projects/ztm_llm_langchain/corso_langchain/lib/python3.13/site-packages
# Requires: certifi, pinecone-plugin-interface, python-dateutil, typing-extensions, urllib3
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pinecone import Pinecone
pc = Pinecone()

pc.list_indexes()
# Out:
# []

# %% [markdown]
# ## Working With pinecone Indexes

# %% [markdown]
# ## Creare un indice

# %%
from pinecone import ServerlessSpec
index_name = 'langchain'
if index_name not in pc.list_indexes().names():
    print(f'Craeating index: {index_name}')
    pc.create_index(
        name=index_name,
        dimension=1536, # Replace with your model dimensions
        metric="cosine", # Replace with your model metric
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        )
    )
    print('Index Created! 🤓')
else:
    print(f'Index {index_name} already exists!')
# Out:
# Craeating index: langchain
# Index Created! 🤓

# %% [markdown]
# ## Cancellare un index

# %%
index_name = 'langchain'
if index_name in pc.list_indexes().names():
    print(f'Deleting index {index_name} ...')
    pc.delete_index(index_name)
    print('Done')
else:
    print(f'Index {index_name} does not exists!')
# Out:
# Deleting index langchain ...
# Done

# %% [markdown]
# ## Operazioni con un indice
# Prima di fare operazioni con un indice dobbiamo selezionarlo

# %%
index = pc.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %% [markdown]
# ## Working with Vectors
# ### Inserting Vectors (random vectors)

# %%
import random
#Creo 5 vettori randomici
vectors = [[random.random() for _ in range(1536)] for v in range(5)]
print(vectors)
# Out:
# [[0.6593800154305917, 0.9647029359135605, 0.025482687628644585, 0.3090109748766994, 0.032615225566080985, 0.9847807557984948, 0.23785587692867494, 0.48271844290103194, 0.8052471437166984, 0.788536844533886, 0.8121580670524675, 0.10986607370858814, 0.263335854822218, 0.9569382479759477, 0.5547805434120243, 0.26102985121286637, 0.05040559808825407, 0.80629596150934, 0.5769060419853533, 0.8952749510387098, 0.5012584533106688, 0.7454171297094879, 0.03898776864904485, 0.4058256151568438, 0.3917992605033904, 0.9420280650186718, 0.4195057579644811, 0.23277331347250108, 0.14904215819146727, 0.31332937040829467, 0.9059535958099154, 0.5130840766758481, 0.6825462218225432, 0.41879284223268654, 0.03508721408832027, 0.18100062285335872, 0.9812917325451161, 0.678892485759447, 0.9426833378666132, 0.03855581291683241, 0.6728894474195843, 0.8668783000142922, 0.9970860093792369, 0.6628393736157154, 0.2485482949946658, 0.656949121035137, 0.6532499541920934, 0.6902234082515794, 0.3170734317055254, 0.2764381376667563, 0.14731545869523766, 0.3753730939744889, 0.6848899461183179, 0.636327197558142, 0.09167124061142273, 1.4777782744723744e-05, 0.3047281922089323, 0.5449813037215916, 0.37328605410906823, 0.24844790585847554, 0.4594206321946054, 0.24328466845253172, 0.1792811811692927, 0.2854907581269174, 0.7095770287262493, 0.7554308225093478, 0.6460380653922128, 0.11820108581816102, 0.06882954585871603, 0.5814280613967726, 0.316783276388771, 0.6253875664835697, 0.5078856709521489, 0.5543843376502562, 0.5645066584825363, 0.693842850933891, 0.8973942786451097, 0.5354487097236724, 0.6711079165191794, 0.3399941964577965, 0.
[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,  ...

# %% [markdown]
# ### Deleting a vectors by id

# %%
index.delete(ids=['b','c'])
# Out:
# {}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 5}},
#  'total_vector_count': 5,
#  'vector_type': 'dense'}

# %%
index.fetch(ids=['x'])
# Out:
# FetchResponse(namespace='', vectors={}, usage={'read_units': 1})

# %% [markdown]
# ## Create a Manual Random Query

# %%
query_vector = [random.random() for _ in range(1536)]

# %% [markdown]
# ### Recuperà i 3 vettori con indice di similarità più alto

# %%
index.query(
    vector = query_vector,
    top_k = 3,
    include_values=False
)
# Out:
# {'matches': [{'id': 'c', 'score': 0.873009086, 'values': []},
#              {'id': 'a', 'score': 0.763750136, 'values': []},
#              {'id': 'b', 'score': 0.760002792, 'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 5}}

# %% [markdown]
# ## Namespace
# Pinecone ti consente di partizionare i vettori in un indice in **Namespaces**.
#
# Le **query** e altre operazioni sono **limitate a uno namespace specifico**, consentendo a diverse richieste di cercare diversi sottoinsiemi del tuo indice.
#
# Informazioni chiave su Namespace:
#
# - Ogni indice è costituito da uno o più Namespace.
# - Ogni vettore esiste esattamente in un Namespace.
# - I Namespace sono identificati in modo univoco da un nome di Namespace.
# - Il Namespace predefinito è rappresentato dalla stringa vuota e viene utilizzato se non viene specificato alcun Namespace specifico.

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 5}},
#  'total_vector_count': 5,
#  'vector_type': 'dense'}

# %% [markdown]
# ### In questo caso vengono inseriti nel name space di default

# %%
index = pc.Index('langchain')

import random
vectors = [[random.random() for _ in range(1536)] for v in range(5)]
ids = list('abcde')
index.upsert(vectors=zip(ids,vectors))
# Out:
# {'upserted_count': 5}

# %% [markdown]
# ### creo 3 nuovi vettori a un namespace specifico

# %%
vectors = [[random.random() for _ in range(1536)] for v in range(3)]
ids = list('xyz')
index.upsert(vectors=zip(ids,vectors), namespace='first-namespace')
# Out:
# {'upserted_count': 3}

# %%
vectors = [[random.random() for _ in range(1536)] for v in range(2)]
ids = list('qp')
index.upsert(vectors=zip(ids,vectors), namespace='second-namespace')
# Out:
# {'upserted_count': 2}

# %% [markdown]
# Tutte le operazioni, esclusa `describe_index_stats()` si applicano a un namespace specifico.

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 5},
#                 'first-namespace': {'vector_count': 3},
#                 'second-namespace': {'vector_count': 2}},
#  'total_vector_count': 10,
#  'vector_type': 'dense'}

# %%
index.fetch(ids=['x'], namespace='first-namespace')
# Out:
# FetchResponse(namespace='first-namespace', vectors={'x': Vector(id='x', values=[0.398842156, 0.486623377, 0.802444816, 0.3589935, 0.625276804, 0.3584086, 0.170400411, 0.859950304, 0.390006065, 0.962989867, 0.773729682, 0.156302661, 0.819633901, 0.805999517, 0.532503, 0.404980123, 0.997192085, 0.962293565, 0.944066107, 0.425263137, 0.205578342, 0.617420852, 0.126189455, 0.174970105, 0.92506808, 0.945442438, 0.640235722, 0.515816689, 0.70458, 0.488399714, 0.404396653, 0.252798378, 0.958925903, 0.74387145, 0.213324189, 0.883281529, 0.928839505, 0.346526712, 0.891748, 0.702137887, 0.457667321, 0.535245, 0.628094792, 0.261259079, 0.156954
304, 0.859247327, 0.406706274, 0.493902504, 0.512027323, 0.754955769, 0.40792, 0.661218047, 0.923842132, 0.428936183, 0.432108909, 0.86912322, 0.262574494, 0.406406313, 0.751388609, 0.392811, 0.751060665, 0.737815738, 0.205300495, 0.704057336, 0.536509156, 0.300938249, 0.723912656, 0.250042677, 0.82992357, 0.949296236, 0.406623304, 0.440877318, 0.549373865, 0.289250016, 0.259460449, 0.186074406, 0.0466667637, 0.242687821, 0.214008182, 0.866750181, 0.993723094, 0.971423388, 0.0394847, 0.557668924, 0.876870155, 0.113317586, 0.00262801093, 0.72484237, 0.449870467, ...

# %%
index.delete(ids=['x'], namespace='first-namespace')
# Out:
# {}

# %%
index.fetch(ids=['x'], namespace='first-namespace')
# Out:
# FetchResponse(namespace='first-namespace', vectors={}, usage={'read_units': 1})

# %% [markdown]
# ### cancellare tutti i record di un namespace, e 🚨cancella anche il namespace

# %%
index.delete(delete_all=True, namespace='first-namespace')
# Out:
# {}

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 5},
#                 'second-namespace': {'vector_count': 2}},
#  'total_vector_count': 7,
#  'vector_type': 'dense'}

# %% [markdown]
# # Splitting and Embeddign Text Using LangChain

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %% [markdown]
# Caricheremo il testo da una repo, ma potremmo caricarlo da qualsiasi tipo di file o sorgente, usando **Transform Loaders**, ci sono service loader su pubblici che privati.
#
# Uno dei **TextSplitter** più usati è `RecursiveCharacterTextSplitter`, di default i caratteri su cui prova a fare lo split sono:
# * Double `\n`
# * `\n`
# * `white space`

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

with open('files/churchill_speech.txt') as f:
    churchill_speech = f.read()
    
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100, # solitamente qui si usa un valore alto, e poi si fanno small chunck
    chunk_overlap=20, # max overlap per garantire continuità( gli ultimi 20 caratteri del primo blocco saranno i primi 20 del secondo blocco)
    length_function=len
)

# %%
chunks = text_splitter.create_documents([churchill_speech])

# %%
print(chunks[10])
# Out:
# page_content='penetration were realized and when a new French Generalissimo, General Weygand, assumed'

# %%
print(chunks[3].page_content)
# Out:
# second week of May, only a rapid retreat to Amiens and the south could have saved the British and

# %%
print(f'Now i have {len(chunks)}')
# Out:
# Now i have 300

# %% [markdown]
# #### Embedding Cost
# Useremo **OpeanAI's text embedding ADA002** che ha un costo, quindi conviene calcolare prima il costo e useremo **tiktoken**

# %%
def print_embedding_cost(texts):
    import tiktoken
    enc = tiktoken.encoding_for_model('text-embedding-ada-002')
    total_tokens = sum([len(enc.encode(page.page_content)) for page in texts])
    print(f'Total Tokens: {total_tokens}')
    print(f'Embdedding Cost in USD: {total_tokens/ 1000  * 0.0004:-6f}')

print_embedding_cost(chunks)
# Out:
# Total Tokens: 4820
# Embdedding Cost in USD: 0.001928

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %% [markdown]
# esempio facciamo embedding della stringa 'abc'

# %%
vector_test = embedding.embed_query('abc')
vector_test
# Out:
# [0.002558193900240056,
#  -0.01136503289795203,
#  -0.009624187024430351,
#  -0.03909118150226145,
#  -0.03444892956482732,
#  0.012016080471193284,
#  -0.021371355549397755,
#  -0.02285744464868338,
#  0.01866809115969756,
#  -0.0003956266204819845,
#  0.00334015888642744,
#  0.01920591505214932,
#  -0.002738647197400543,
#  -0.004521952533294896,
#  -0.01869639777838687,
#  0.0029969434631259926,
#  0.027032642034356784,
#  0.010600758849953526,
#  0.010820133747811817,
#  0.007487051283226059,
#  -0.014521199461390879,
#  0.017833052427620944,
#  -0.0070058420251368,
01775675620881649, 0.007603665402087385, -0.011376816397940834, -5.8208589157403496e-05, 0.012320104496150123, 0.04007698878138462, -0.014786674797501726, -0.014060088673594144, -0.0002463781863677299, 0.023225276844986313, 0.028834015529165504, 0.00853420602402754, 0.0032266181430120836, -0.009936390229411103, 0.009337275142904989, -0.006704992306666982, 0.020484644418581152, -0.0008421075373559957, 0.022957586828253006, 0.013409984613333963, -0.0135884446244895, 0.026590521173080788, -0.013104053564776957, -0.000787533845218208, 0.04045940096226656, 0.030236201597194003, 0.03041466160834954, 0.010956161322590259, 0.041785104966647654, 0.013180536559746825, 0.024104828958833632, 0.00878277505918776, -0.01090517234883619, 0.025889429070389006, 0.012249995472145437, 0.010739460279611021, -0.007903222945340441, 0.0028410173468332335, -0.0030385978739006212, 0.03426429606483409, 0.02249869072107873, -0.002885632349622118, -0.0028617315883169964,  ...

# %% [markdown]
# ## Inserting the Embeddigns into A pinecone Index

# %%
pip install langchain-pinecone
# Out:
# Collecting langchain-pinecone
#   Downloading langchain_pinecone-0.2.4-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in ./corso_langchain/lib/python3.13/site-packages (from langchain-pinecone) (0.3.49)
# Requirement already satisfied: pinecone<7.0.0,>=6.0.0 in ./corso_langchain/lib/python3.13/site-packages (from pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (6.0.1)
# Collecting aiohttp<3.11,>=3.10 (from langchain-pinecone)
#   Downloading aiohttp-3.10.11-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.26.4 in ./corso_langchain/lib/python3.13/site-packages (from langchain-pinecone) (2.2.3)
# Collecting langchain-tests<1.0.0,>=0.3.7 (from langchain-pinecone)
#   Downloading langchain_tests-0.3.17-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./corso_langchain/lib/python3.13/site-packages (from aiohttp<3.11,>=3.10->langchain-pinecone) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in ./corso_langchain/lib/python3.13/site-packages (from aiohttp<3.11,>=3.10->langchain-pinecone) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./corso_langchain/lib/python3.13/site-packages (from aiohttp<3.11,>=3.10->langchain-pinecone) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./corso_langchain/lib/python3.13/site-packages (from aiohttp<3.11,>=3.10->langchain-pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./corso_langchain/lib/python3.13/site-packages (from aiohttp<3.11,>=3.10->langchain-pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./corso_langchain/lib/python3.13/site-packages (from aiohttp<3.11,>=3.10->langchain-pinecone) (1.18.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.3.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./corso_langchain/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.10.6)
# Collecting pytest<9,>=7 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-asyncio<1,>=0.20 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading pytest_asyncio-0.26.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./corso_langchain/lib/python3.13/site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.28.1)
# Collecting syrupy<5,>=4 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading syrupy-4.9.1-py3-none-any.whl.metadata (38 kB)
# Collecting pytest-socket<1,>=0.6.0 (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading pytest_socket-0.7.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi>=2019.11.17 in ./corso_langchain/lib/python3.13/site-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (2025.1.31)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in ./corso_langchain/lib/python3.13/site-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./corso_langchain/lib/python3.13/site-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in ./corso_langchain/lib/python3.13/site-packages (from pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (2.3.0)
# WARNING: pinecone 6.0.1 does not provide the extra 'async'
# Requirement already satisfied: anyio in ./corso_langchain/lib/python3.13/site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.8.0)
# Requirement already satisfied: httpcore==1.* in ./corso_langchain/lib/python3.13/site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.0.7)
# Requirement already satisfied: idna in ./corso_langchain/lib/python3.13/site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in ./corso_langchain/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./corso_langchain/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./corso_langchain/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in ./corso_langchain/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./corso_langchain/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./corso_langchain/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./corso_langchain/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./corso_langchain/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.27.2)
# Collecting iniconfig (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: six>=1.5 in ./corso_langchain/lib/python3.13/site-packages (from python-dateutil>=2.5.3->pinecone<7.0.0,>=6.0.0->pinecone[async]<7.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in ./corso_langchain/lib/python3.13/site-packages (from yarl<2.0,>=1.12.0->aiohttp<3.11,>=3.10->langchain-pinecone) (0.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./corso_langchain/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in ./corso_langchain/lib/python3.13/site-packages (from anyio->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.3.1)
# Downloading langchain_pinecone-0.2.4-py3-none-any.whl (16 kB)
# Downloading aiohttp-3.10.11-cp313-cp313-macosx_11_0_arm64.whl (388 kB)
# Downloading langchain_tests-0.3.17-py3-none-any.whl (39 kB)
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
# Downloading pytest_asyncio-0.26.0-py3-none-any.whl (19 kB)
# Downloading pytest_socket-0.7.0-py3-none-any.whl (6.8 kB)
# Downloading syrupy-4.9.1-py3-none-any.whl (52 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Installing collected packages: pluggy, iniconfig, pytest, aiohttp, syrupy, pytest-socket, pytest-asyncio, langchain-tests, langchain-pinecone
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.12
#     Uninstalling aiohttp-3.11.12:
#       Successfully uninstalled aiohttp-3.11.12
# Successfully installed aiohttp-3.10.11 iniconfig-2.1.0 langchain-pinecone-0.2.4 langchain-tests-0.3.17 pluggy-1.5.0 pytest-8.3.5 pytest-asyncio-0.26.0 pytest-socket-0.7.0 syrupy-4.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
import pinecone


pc = pinecone.Pinecone()

# %%
# On free plan i need to delete the existing 
for i in pc.list_indexes().names():
    print('Deleting all indexes...',end="")
    pc.delete_index(i)
    print('Done')
# Out:
# Deleting all indexes...Done

# %%
index_name = 'churchill-speech'

# Ottieni la lista degli indici
existing_indexes = pc.list_indexes()
print("Indici esistenti:", existing_indexes)

# Verifica se l'indice esiste già nella lista degli indici
if index_name not in [index.name for index in existing_indexes]:
    print(f'Creating Index {index_name}...')
    pc.create_index(
        name=index_name,
        dimension=1536,
        metric='cosine',
        spec=pinecone.ServerlessSpec(
            cloud='aws',
            region='us-east-1'
        )
    )
    print('Done')
    # Aspetta che l'indice sia pronto
    import time
    time.sleep(60)
else:
    print(f'Index {index_name} already exists, skipping creation.')
# Out:
# Indici esistenti: [{
#     "name": "churchill-speech",
#     "metric": "cosine",
#     "host": "churchill-speech-i8se1nd.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null
# }]
# Index churchill-speech already exists, skipping creation.

# %%
# Accedi all'indice esistente
index = pc.Index(index_name)

# %%
print(index)
# Out:
# <pinecone.data.index.Index object at 0x11b7eb680>

# %%
vector_store = PineconeVectorStore.from_documents(
    documents=chunks, 
    embedding=embeddings, 
    index_name=index_name  # Usa index_name invece di index
)

# %%
print(pinecone.__version__)
# Out:
# 6.0.1

# %%
# Ottieni prima l'oggetto index
index = pc.Index("churchill-speech")

# Poi crea il vector store
vector_store = PineconeVectorStore(
    index=index,
    embedding=embeddings,
    text_key="text"
)

# %% [markdown]
# ## Asking Questions (Similarity Search)

# %%
query = 'Where should we fight?'
matching_docs = vector_store.similarity_search(query)

print(matching_docs)
# Out:
# [Document(id='0fe5fc01-9efe-46d9-8440-abc6707827be', metadata={}, page_content='shall fight on the beaches, we shall fight on the landing grounds, we shall fight in the fields and'), Document(id='2eba45a8-cb6c-4f2d-ac07-6c60f5f5d427', metadata={}, page_content='front, now on that, fighting'), Document(id='2468745f-7611-4e01-886d-268b3dbdf93d', metadata={}, page_content='end, we shall fight in France, we shall fight on the seas and oceans, we shall fight with growing'), Document(id='ff0ed3c1-d511-4d54-92ff-a588ac5ec193', metadata={}, page_content='When we consider how much greater would be our advantage in defending the air above this Island')]

# %%
for r in matching_docs:
    print(r.page_content)
    print('-' * 50 )
# Out:
# shall fight on the beaches, we shall fight on the landing grounds, we shall fight in the fields and
# --------------------------------------------------
# front, now on that, fighting
# --------------------------------------------------
# end, we shall fight in France, we shall fight on the seas and oceans, we shall fight with growing
# --------------------------------------------------
# When we consider how much greater would be our advantage in defending the air above this Island
# --------------------------------------------------

# %% [markdown]
# ###  Integro con un Retriever di LangChain

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-3.5-turbo', temperature=1)

retriever = vector_store.as_retriever(search_type='similarity', search_kwargs={'k':3})

chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

# %%
query = 'Where should we fight?'
answer = chain.invoke(query)
print(answer)
# Out:
# {'query': 'Where should we fight?', 'result': 'Based on the provided context, it seems that the question is related to a speech by Winston Churchill during World War II. In the speech, he mentions fighting on beaches, landing grounds, fields, fronts, in France, on seas, and oceans. So, the answer would be that we should fight in various locations both on land and at sea.'}

# %% [markdown]
# Se chiediamo una domanda due volte la risposta sarà diversa.
